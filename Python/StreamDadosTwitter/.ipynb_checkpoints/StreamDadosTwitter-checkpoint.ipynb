# %% [markdown]
# ### Stream de Dados do Twitter com MongoDB, Pandas e Scikit Learn

# %%
# Importando os módulos Tweepy, Datetime e Json
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
from datetime import datetime
import json

# %%
# Consumer Key 
consumer_key = ""

# %%
# Consumer secret
consumer_secret = ""

# %%
# Acess Token
access_token = ""

# %%
# Acess Token Secret
access_token_secret = ""

# %%
# Criando as chaves de autenticação
auth = OAuthHandler(consumer_key, consumer_secret)

# %%
auth.set_access_token(access_token, access_token_secret)

# %%
# Criando uma classe para capturar os stream de dados do Twitter e 
# armazenar no MongoDB
class MyListener(StreamListener):
    def on_data(self, dados):
        tweet = json.loads(dados)
        created_at = tweet["created_at"]
        id_str = tweet["id_str"]
        text = tweet["text"]
        obj = {"created_at":created_at,"id_str":id_str,"text":text,}
        tweetind = col.insert_one(obj).inserted_id
        print (obj)
        return True

# %%
# Criando o objeto mylistener
mylistener = MyListener()

# %%
# Criando o objeto mystream
mystream = Stream(auth, listener = mylistener)

# %% [markdown]
# ### Preparando a Conexão com o MongoDB

# %%
# Importando do PyMongo o módulo MongoClient
from pymongo import MongoClient

# %%
# Criando a conexão ao MongoDB
client = MongoClient('mongodb://localhost:27017/')

# %%
# To show all database name
client.list_database_names()
# Out:
# ['admin', 'config', 'local']

# %%
# Criando o banco de dados twitterdb
db = client.twitterdb

# %%
# Criando a collection "col"
col = db.tweets

# %%
# Criando uma lista de palavras chave para buscar nos Tweets
keywords = ['Brasil', 'Argentina', 'Neymar', 'Messi', 'Copa América']

# %%
# Iniciando o filtro e gravando os tweets no MongoDB
mystream.filter(track=keywords)
# Out:
# {'created_at': 'Sat Jul 10 23:09:26 +0000 2021', 'id_str': '1413998827741319168', 'text': 'Vamos genio! No será fácil pero esta vez puede ser ! Vamos argentina dárselo a Lionel por todo lo que os da y lo q… https://t.co/tmOFg3Ecvc', '_id': ObjectId('60ea28ab0239d712af29c7b9')}
# {'created_at': 'Sat Jul 10 23:09:26 +0000 2021', 'id_str': '1413998827883925507', 'text': 'RT @neymarjrdepre: Tite querendo inventar logo na final, botou o Neymar de goleiro… https://t.co/Rm7NcTPu5b', '_id': ObjectId('60ea28ab0239d712af29c7ba')}
# {'created_at': 'Sat Jul 10 23:09:26 +0000 2021', 'id_str': '1413998827879731203', 'text': '@btsargento @BTS_twt Argentina\n#KCAMexico #BTS #Butter #ARMY \n@BTS_twt', '_id': ObjectId('60ea28ab0239d712af29c7bb')}
# {'created_at': 'Sat Jul 10 23:09:26 +0000 2021', 'id_str': '1413998827959377922', 'text': 'RT @brfootball: 📍 Rosario, Argentina\n\nMessi’s hometown lit up the National Flag Memorial last night in preparation for the Copa America fin…', '_id': ObjectId('60ea28ab0239d712af29c7bc')}
# {'created_at': 'Sat Jul 10 23:09:26 +0000 2021', 'id_str': '1413998828013903872', 'text': 'RT @acessosonzers: RECONHECIDA! Dos 7.346.846 de ouvintes mensais que a cantora Luísa Sonza possui no Spotify, 2.458.594 são de fora do Bra…', '_id': ObjectId('60ea28ab0239d712af29c7bd')}
# {'created_at': 'Sat Jul 10 23:09:26 +0000 2021', 'id_str': '1413998827879686147', 'text': 'RT @CBF_Futebol: A #SeleçãoBrasileira está escalada para enfrentar a Argentina na decisão da CONMEBOL @CopaAmerica!\n\n🇧🇷 x 🇦🇷 - 21h | #BRAxA…', '_id': ObjectId('60ea28ab0239d712af29c7be')}
# {'created_at': 'Sat Jul 10 23:09:26 +0000 2021', 'id_str': '1413998827972042755', 'text': "L'argentine je ne sais pas s'ils vont faire un exploit et battre le Brésil dans leur pays de magouilles là mais le… https://t.co/Z7SmdXtjfV", '_id': ObjectId('60ea28ab0239d712af29c7bf')}
# {'created_at': 'Sat Jul 10 23:09:26 +0000 2021', 'id_str': '1413998828206891014', 'text': 'RT @CBF_Futebol: A #SeleçãoBrasileira está escalada para enfrentar a Argentina na decisão da CONMEBOL @CopaAmerica!\n\n🇧🇷 x 🇦🇷 - 21h | #BRAxA…', '_id': ObjectId('60ea28ab0239d712af29c7c0')}
# {'created_at': 'Sat Jul 10 23:09:26 +0000 2021', 'id_str': '1413998828357836803', 'text': 'RT @Adriana20895760: Buenassssss, Hoy es el Día, me voy a INOCULAR EL VENENO y juega ARGENTINA 🇦🇷😘...\nEXCELENTE FINDE PARA TODOS/AS✌️✌️✌️✌️…', '_id': ObjectId('60ea28ab0239d712af29c7c1')}
# {'created_at': 'Sat Jul 10 23:09:26 +0000 2021', 'id_str': '1413998828315975687', 'text': '@jornalnacional Lula é um narcisista, só pensa em sim, foi informante do Tuma, diretor sindical amigão dos patrões,… https://t.co/otRP7d0wLo', '_id': ObjectId('60ea28ab0239d712af29c7c2')}
# {'created_at': 'Sat Jul 10 23:09:26 +0000 2021', 'id_str': '1413998828278198274', 'text': 'Van pasando los años , te acordás del mundial del 50 ,están todos cagados tienen miedo que pase devuelta , Porque M… https://t.co/mmEQDwRuC1', '_id': ObjectId('60ea28ab0239d712af29c7c3')}
# {'created_at': 'Sat Jul 10 23:09:26 +0000 2021', 'id_str': '1413998828420800514', 'text': 'RT @ImAgus51: Hoy se banca a argentina', '_id': ObjectId('60ea28ab0239d712af29c7c4')}
# {'created_at': 'Sat Jul 10 23:09:26 +0000 2021', 'id_str': '1413998828043317248', 'text': 'Fav si queres que gane Messi la Copa America 🇦🇷🏆', '_id': ObjectId('60ea28ab0239d712af29c7c5')}
# {'created_at': 'Sat Jul 10 23:09:26 +0000 2021', 'id_str': '1413998828504723458', 'text': 'Só quero a vitória do Brasil hoje e a vitória da Itália amanhã', '_id': ObjectId('60ea28ab0239d712af29c7c6')}
# {'created_at': 'Sat Jul 10 23:09:26 +0000 2021', 'id_str': '1413998828601159688', 'text': 'RT @JamilChade: Brasil campeão é um Brasil que derrota um vírus e um verme. Que retoma emprego e prato de comida na mesa. Um Brasil campeão…', '_id': ObjectId('60ea28ab0239d712af29c7c7')}
# {'created_at': 'Sat Jul 10 23:09:26 +0000 2021', 'id_str': '1413998828714401792', 'text': 'Torcer contra o Brasil é ter votado em Bolsonaro e não torcer para Argentina.', '_id': ObjectId('60ea28ab0239d712af29c7c8')}
# {'created_at': 'Sat Jul 10 23:09:26 +0000 2021', 'id_str': '1413998828697571330', 'text': 'RT @Messismo10: Argentina ya llegó al Maracaná. https://t.co/KedWFeu5BW', '_id': ObjectId('60ea28ab0239d712af29c7c9')}
# {'created_at': 'Sat Jul 10 23:09:26 +0000 2021', 'id_str': '1413998828684992512', 'text': 'RT @CBF_Futebol: A #SeleçãoBrasileira está escalada para enfrentar a Argentina na decisão da CONMEBOL @CopaAmerica!\n\n🇧🇷 x 🇦🇷 - 21h | #BRAxA…', '_id': ObjectId('60ea28ab0239d712af29c7ca')}
# {'created_at': 'Sat Jul 10 23:09:26 +0000 2021', 'id_str': '1413998828798218241', 'text': 'Que gane Brasil y robando.', '_id': ObjectId('60ea28ab0239d712af29c7cb')}
# {'created_at': 'Sat Jul 10 23:09:26 +0000 2021', 'id_str': '1413998828609544194', 'text': '@Abenz96 *Neymar', '_id': ObjectId('60ea28ab0239d712af29c7cc')}
# {'created_at': 'Sat Jul 10 23:09:26 +0000 2021', 'id_str': '1413998828836073477', 'text': '@CuriosidadesBRL @luckybetingg @CuriosidadesPRL Brasil 2 x Argentina 0\nricharlison e neymar', '_id': ObjectId('60ea28ab0239d712af29c7cd')}
# {'created_at': 'Sat Jul 10 23:09:26 +0000 2021', 'id_str': '1413998828882173953', 'text': 'RT @neymarjrdepre: Tite querendo inventar logo na final, botou o Neymar de goleiro… https://t.co/Rm7NcTPu5b', '_id': ObjectId('60ea28ab0239d712af29c7ce')}
# {'created_at': 'Sat Jul 10 23:09:26 +0000 2021', 'id_str': '1413998828806619136', 'text': 'hoy juega argentina https://t.co/u1kbBuOJtP', '_id': ObjectId('60ea28ab0239d712af29c7cf')}
# {'created_at': 'Sat Jul 10 23:09:26 +0000 2021', 'id_str': '1413998829029011464', 'text': 'RT @JoseMontalva6: @DonBisca La diferencia esta ,q. Argentina tiene al mejor jugador del mundo mientras q.Brasil tiene al mejor Payaso del…', '_id': ObjectId('60ea28ab0239d712af29c7d0')}
# {'created_at': 'Sat Jul 10 23:09:26 +0000 2021', 'id_str': '1413998828928356360', 'text': '@Rashford7i fred and neymar dunking on messi head today', '_id': ObjectId('60ea28ab0239d712af29c7d1')}
# {'created_at': 'Sat Jul 10 23:09:26 +0000 2021', 'id_str': '1413998829037367298', 'text': '@OrmaetxeaJon la única razón por la q quiero q gane Argentina es para q duki y biza saquen una sessiom', '_id': ObjectId('60ea28ab0239d712af29c7d2')}
# {'created_at': 'Sat Jul 10 23:09:26 +0000 2021', 'id_str': '1413
}
# {'created_at': 'Sat Jul 10 23:09:27 +0000 2021', 'id_str': '1413998831965032450', 'text': 'Sobre o jogo a seguir: não assistir o jogo não te faz especial, torcer pra Argentina tbm não. E dizer que é patriot… https://t.co/qn3nTqhWnK', '_id': ObjectId('60ea28ac0239d712af29c7f2')}
# {'created_at': 'Sat Jul 10 23:09:27 +0000 2021', 'id_str': '1413998832149536770', 'text': '@0URK00K Argentina', '_id': ObjectId('60ea28ac0239d712af29c7f3')}
# {'created_at': 'Sat Jul 10 23:09:27 +0000 2021', 'id_str': '1413998832199905289', 'text': '@YMCBahia O Casão acaba de me convencer a fazer um força e ver jogo da final para torcer para Argentina!🇦🇷🇦🇷🇦🇷🇦🇷🇦🇷🇦🇷🇦🇷🇦🇷🇦🇷🇦🇷🇦🇷🇦🇷🇦🇷', '_id': ObjectId('60ea28ac0239d712af29c7f4')}
# {'created_at': 'Sat Jul 10 23:09:27 +0000 2021', 'id_str': '1413998832166244352', 'text': '@blogdocarlao Messi tem mais é que se foder junto com os Argentinos todos ...', '_id': ObjectId('60ea28ac0239d712af29c7f5')}
# {'created_at': 'Sat Jul 10 23:09:27 +0000 2021', 'id_str': '1413998832287985667', 'text': 'RT @CBF_Futebol: A #SeleçãoBrasileira está escalada para enfrentar a Argentina na decisão da CONMEBOL @CopaAmerica!\n\n🇧🇷 x 🇦🇷 - 21h | #BRAxA…', '_id': ObjectId('60ea28ac0239d712af29c7f6')}
# {'created_at': 'Sat Jul 10 23:09:27 +0000 2021', 'id_str': '1413998832350908420', 'text': '@Loic93B même si elle aime messi elle passera après lui', '_id': ObjectId('60ea28ac0239d712af29c7f7')}
# {'created_at': 'Sat Jul 10 23:09:27 +0000 2021', 'id_str': '1413998832388542464', 'text': 'perdón por la persona en la que me voy a convertir si gana o pierde brasil no saben lo que odio a neymar en un odio… https://t.co/OPYU0V0Y1I', '_id': ObjectId('60ea28ac0239d712af29c7f8')}
# {'created_at': 'Sat Jul 10 23:09:27 +0000 2021', 'id_str': '1413998832510242817', 'text': 'Quera compra a blusa do Brasil branca, acho ela muito linda', '_id': ObjectId('60ea28ac0239d712af29c7f9')}
# {'created_at': 'Sat Jul 10 23:09:27 +0000 2021', 'id_str': '1413998832564703236', 'text': 'RT @theMadridZone: 🎙️| Ronaldo Nazario: "Messi has 0 trophies with Argentina? I wouldn\'t get into that, because I have 0 UCLs with Real Mad…', '_id': ObjectId('60ea28ac0239d712af29c7fa')}
# {'created_at': 'Sat Jul 10 23:09:27 +0000 2021', 'id_str': '1413998832543838208', 'text': 'Brasil d por lejos ...', '_id': ObjectId('60ea28ac0239d712af29c7fb')}
# {'created_at': 'Sat Jul 10 23:09:27 +0000 2021', 'id_str': '1413998832673771522', 'text': 'RT @sport: #FinalCopaAmerica 🏆\n\n🤔 ¿Quién quieres que gane la gran final?\n\n❤ Argentina\n\n🔁 Brasil https://t.co/22p8pSMW0I', '_id': ObjectId('60ea28ac0239d712af29c7fc')}
# {'created_at': 'Sat Jul 10 23:09:27 +0000 2021', 'id_str': '1413998832665473027', 'text': "Even Brazillians know how much Messi deserves this cup..it would truly be a shame if things don't work out for him… https://t.co/pfEOp90OCq", '_id': ObjectId('60ea28ac0239d712af29c7fd')}
# {'created_at': 'Sat Jul 10 23:09:27 +0000 2021', 'id_str': '1413998832938070019', 'text': 'RT @todoscomciro: Falem o que quiserem, mas Ciro está com tendência de crescimento nas pesquisas, nas redes sociais e em todo o Brasil!\n\nNu…', '_id': ObjectId('60ea28ac0239d712af29c7fe')}
# {'created_at': 'Sat Jul 10 23:09:27 +0000 2021', 'id_str': '1413998832849887233', 'text': '@DesmondAduTwum1 @KinaataGh Messi naa', '_id': ObjectId('60ea28ac0239d712af29c7ff')}
# {'created_at': 'Sat Jul 10 23:09:27 +0000 2021', 'id_str': '1413998832921284608', 'text': "RT @ElCerebr0: Nevermind the defense. I'm hearing all out attack by Scaloni 👀 Lo Celso, Paredes, De Paul, Messi, Lautaro and Di Maria 🔥", '_id': ObjectId('60ea28ac0239d712af29c800')}
# {'created_at': 'Sat Jul 10 23:09:27 +0000 2021', 'id_str': '1413998833118244864', 'text': 'RT @UNIVERSO_1899: Círculo de oración:\n\n                    🕯       🕯\n           🕯                         🕯\n                      MESSI…', '_id': ObjectId('60ea28ac0239d712af29c801')}
# {'created_at': 'Sat Jul 10 23:09:27 +0000 2021', 'id_str': '1413998833055539201', 'text': 'No puedo imaginar otra cosa que Messi empujando da pedotita hacia el arco de Bras*l.', '_id': ObjectId('60ea28ac0239d712af29c802')}
# {'created_at': 'Sat Jul 10 23:09:27 +0000 2021', 'id_str': '1413998833122652162', 'text': 'RT @flickervibes_: listo cambié el nombre por cábala porque es lo único que me queda. \nsi no vieron los otros partidos, HOY NO HAGAN UNA EX…', '_id': ObjectId('60ea28ac0239d712af29c803')}
# {'created_at': 'Sat Jul 10 23:09:27 +0000 2021', 'id_str': '1413998833047121921', 'text': 'RT @aiturrusgarai: Em abril o Brasil atingiu a marca de 400.000 mortos por Covid e o UOL fez uma matéria focando na saúde mental durante a…', '_id': ObjectId('60ea28ac0239d712af29c804')}
# {'created_at': 'Sat Jul 10 23:09:27 +0000 2021', 'id_str': '1413998833445576706', 'text': 'RT @futebol_info: 🇧🇷 Seleção Brasileira escalada:\n\nEderson\nDanilo\nThiago Silva\nMarquinhos\nRenan Lodi\n\nCasemiro\nFred\nLucas Paquetá\n\nNeymar\nÉ…', '_id': ObjectId('60ea28ac0239d712af29c805')}
# {'created_at': 'Sat Jul 10 23:09:27 +0000 2021', 'id_str': '1413998833722351616', 'text': 'hj é dia bater em brasileiro que torce pra argentina', '_id': ObjectId('60ea28ac0239d712af29c806')}
# {'created_at': 'Sat Jul 10 23:09:27 +0000 2021', 'id_str': '1413998833462353920', 'text': "RT @WelBeast: I stopped taking La Liga seriously when they allowed Barcelona to sign a relegation battling side's main striker mid season b…", '_id': ObjectId('60ea28ac0239d712af29c807')}
# {'created_at': 'Sat Jul 10 23:09:27 +0000 2021', 'id_str': '1413998833642639362', 'text': 'RT @albuquerquedavy: 1) Lula solto\n2) Lula elegível \n3) Aprovação de Bolsonaro em queda \n4) Lula disparado nas pesquisas \n5) Articulações i…', '_id': ObjectId('60ea28ac0239d712af29c808')}
# {'created_at': 'Sat Jul 10 23:09:27 +0000 2021', 'id_str': '1413998833659523073', 'text': 'RT @futpicante: ¡ABRIMOS DEBATE! ✋\n\n¿Messi es el actual mejor jugador del mundo? 🔥⚽\n\n🔃 RT: Sí\n❤ MG: No \n\nhttps://t.co/6rZZ0HD7gM https://t.…', '_id': ObjectId('60ea28ac0239d712af29c809')}
# {'created_at': 'Sat Jul 10 23:09:27 +0000 2021', 'id_str': '1413998833659490310', 'text': '@Marietre2 Brasil creo; Mis hijas x Argentina jugamos una Apuesta..\nJajaja 😂😂😆✌💋💋', '_id': ObjectId('60ea28ac0239d712af29c80a')}
# {'created_at': 'Sat Jul 10 23:09:27 +0000 2021', 'id_str': '1413998833848160256', 'text': 'Brasil definido!', '_id': ObjectId('60ea28ac0239d712af29c80b')}
# {'created_at': 'Sat Jul 10 23:09:27 +0000 2021', 'id_str': '1413998833969897472', 'text': '@rmartinelli Argentina-Italia', '_id': ObjectId('60ea28ac0239d712af29c80c')}
# {'created_at': 'Sat Jul 10 23:09:27 +0000 2021', 'id_str': '1413998833927966721', 'text': 'RT @SarkcessObed: Watch Live Discussion Of The #CopaAmericaFINAL.\n\nArgentina vs. Brazil \n\nFollow @richdudegh for Live Stream when the match…', '_id': ObjectId('60ea28ac0239d712af29c80d')}
# {'created_at': 'Sat Jul 10 23:09:27 +0000 2021', 'id_str': '1413998834506682368', 'text': 'Uyuyorum ben sabah Kalktığımds Messi Kupa kazanmış olur umarım', '_id': ObjectId('60ea28ac0239d712af29c80e')}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-6a9070444200> in <module>
#       1 # Iniciando o filtro e gravando os tweets no MongoDB
# ----> 2 mystream.filter(track=keywords)
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     318             # call a handler first so that the exception can be logged.
#     319             self.listener.on_exception(exc_info[1])
# --> 320             six.reraise(*exc_info)
#     321
#     322     def _data(self, data):
#
# ~\anaconda3\lib\site-packages\six.py in reraise(tp, value, tb)
#     717             if value.__traceback__ is not tb:
#     718                 raise value.with_traceback(tb)
# --> 719             raise value
#     720         finally:
#     721             value = None
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     349             next_status_obj = buf.read_len(length)
#     350             if self.running and next_status_obj:
# --> 351                 self._data(next_status_obj)
#     352
#     353             # # Note: keep-alive newlines might be inserted before each length value.
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _data(self, data)
#     321
#     322     def _data(self, data):
# --> 323         if self.listener.on_data(data) is False:
#     324             self.running = False
#     325
#
# <ipython-input-14-942f63673ccb> in on_data(self, dados)
#       4     def on_data(self, dados):
#       5         tweet = json.loads(dados)
# ----> 6         created_at = tweet["created_at"]
#       7         id_str = tweet["id_str"]
#       8         text = tweet["text"]
#
# KeyError: 'created_at'

# %%
mystream.disconnect()

# %%
# Verificando um documento no collection
col.find_one()
# Out:
# {'_id': ObjectId('60ea28ab0239d712af29c7b9'),
#  'created_at': 'Sat Jul 10 23:09:26 +0000 2021',
#  'id_str': '1413998827741319168',
#  'text': 'Vamos genio! No será fácil pero esta vez puede ser ! Vamos argentina dárselo a Lionel por todo lo que os da y lo q… https://t.co/tmOFg3Ecvc'}

# %% [markdown]
# #### Análise de Dados com Pandas e Scikit-Learn

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

# %%
# criando um dataset com dados retornados do MongoDB
dataset = [{"created_at": item["created_at"], "text": item["text"],} for item in col.find()]

# %%
# Criando um dataframe a partir do dataset 
df = pd.DataFrame(dataset)

# %%
df
# Out:
#                         created_at  \
# 0   Sat Jul 10 23:09:26 +0000 2021
# 1   Sat Jul 10 23:09:26 +0000 2021
# 2   Sat Jul 10 23:09:26 +0000 2021
# 3   Sat Jul 10 23:09:26 +0000 2021
# 4   Sat Jul 10 23:09:26 +0000 2021
# ..                             ...
# 81  Sat Jul 10 23:09:27 +0000 2021
# 82  Sat Jul 10 23:09:27 +0000 2021
# 83  Sat Jul 10 23:09:27 +0000 2021
# 84  Sat Jul 10 23:09:27 +0000 2021
# 85  Sat Jul 10 23:09:27 +0000 2021
#
#                                                  text
# 0   Vamos genio! No será fácil pero esta vez puede...
# 1   RT @neymarjrdepre: Tite querendo inventar logo...
# 2   @btsargento @BTS_twt Argentina\n#KCAMexico #BT...
# 3   RT @brfootball: 📍 Rosario, Argentina\n\nMessi’...
# 4   RT @acessosonzers: RECONHECIDA! Dos 7.346.846 ...
# ..                                                ...
# 81  @Marietre2 Brasil creo; Mis hijas x Argentina ...
# 82                                   Brasil definido!
# 83                      @rmartinelli Argentina-Italia
# 84  RT @SarkcessObed: Watch Live Discussion Of The...
# 85  Uyuyorum ben sabah Kalktığımds Messi Kupa kaza...
#
# [86 rows x 2 columns]

# %%
# Usando o método CountVectorizer para criar uma matriz de documentos
cv = CountVectorizer()
count_matrix = cv.fit_transform(df.text)

# %%
# Contando o número de ocorrências das principais palavras em nosso dataset
word_count = pd.DataFrame(cv.get_feature_names(), columns=["word"])
word_count["count"] = count_matrix.sum(axis=0).tolist()[0]
word_count = word_count.sort_values("count", ascending=False).reset_index(drop=True)
word_count[:50]
# Out:
#                  word  count
# 0                  rt     52
# 1           argentina     38
# 2                  de     28
# 3                 que     28
# 4               https     27
# 5                  co     26
# 6               messi     23
# 7              brasil     22
# 8                  la     20
# 9                  da     13
# 10               para     12
# 11                 no     11
# 12             neymar     11
# 13                 el     10
# 14                por     10
# 15                 na     10
# 16                 si      9
# 17              final      8
# 18                 lo      8
# 19                 um      7
# 20               copa      7
# 21           conmebol      6
# 22               gane      6
# 23                 em      6
# 24                não      6
# 25                 me      6
# 26           escalada      6
# 27                 en      6
# 28               está      6
# 29                the      6
# 30                del      5
# 31              vamos      5
# 32                 to      5
# 33                21h      5
# 34              braxa      5
# 35                 do      5
# 36        cbf_futebol      5
# 37                dos      5
# 38  seleçãobrasileira      5
# 39            decisão      5
# 40        copaamerica      5
# 41          enfrentar      5
# 42                 un      5
# 43                 le      5
# 44                 es      4
# 45                hoy      4
# 46               lula      4
# 47                 vs      4
# 48                 se      4
# 49              todos      4
