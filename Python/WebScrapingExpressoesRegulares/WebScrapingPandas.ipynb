# %% [markdown]
# ### Extraindo e manipulando dados de uma URL

# %%
import pandas as pd
import urllib.request # Biblioteca usada para requisitar uma página de um web site
from bs4 import BeautifulSoup

# %%
with urllib.request.urlopen("http://espn.go.com/nfl/superbowl/history/winners") as url:
    page = url.read()

# %%
soup = BeautifulSoup(page, "html.parser")

# %%
# Extrai a tabela do código HTML
table = soup.find_all('table')[0]

# %%
print(table)
# Out:
# <table border="0" cellpadding="3" cellspacing="1" class="tablehead" width="100%">
# <tr class="stathead">
# <td colspan="4">Super Bowl Winners and Results</td>
# </tr>
# <tr class="colhead">
# <td>NO.</td>
# <td>DATE</td>
# <td>SITE</td>
# <td>RESULT</td>
# </tr>
# <tr class="oddrow">
# <td>I</td>
# <td>Jan. 15, 1967</td>
# <td>Los Angeles Memorial Coliseum</td>
# <td>Green Bay 35, Kansas City 10</td>
# </tr>
# <tr class="evenrow">
# <td>II</td>
# <td>Jan. 14, 1968</td>
# <td>Orange Bowl (Miami)</td>
# <td>Green Bay 33, Oakland 14</td>
# </tr>
# <tr class="oddrow">
# <td>III</td>
# <td>Jan. 12, 1969</td>
# <td>Orange Bowl (Miami)</td>
# <td>New York Jets 16, Baltimore 7</td>
# </tr>
# <tr class="evenrow">
# <td>IV</td>
# <td>Jan. 11, 1970</td>
# <td>Tulane Stadium (New Orleans)</td>
# <td>Kansas City 23, Minnesota 7</td>
# </tr>
# <tr class="oddrow">
# <td>V</td>
# <td>Jan. 17, 1971</td>
# <td>Orange Bowl (Miami)</td>
# <td>Baltimore 16, Dallas 13</td>
# </tr>
# <tr class="evenrow">
# <td>VI</td>
# <td>Jan. 16, 1972</td>
# <td>Tulane Stadium (New Orleans)</td>
# <td>Dallas 24, Miami 3</td>
# </tr>
# <tr class="oddrow">
# <td>VII</td>
# <td>Jan. 14, 1973</td>
# <td>Los Angeles Memorial Coliseum</td>
# <td>Miami 14, Washington 7</td>
# </tr>
# <tr class="evenrow">
# <td>VIII</td>
# <td>Jan. 13, 1974</td>
# <td>Rice Stadium (Houston)</td>
# <td>Miami 24, Minnesota 7</td>
# </tr>
# <tr class="oddrow">
# <td>IX</td>
# <td>Jan. 12, 1975</td>
# <td>Tulane Stadium (New Orleans)</td>
# <td>Pittsburgh 16, Minnesota 6</td>
# </tr>
# <tr class="evenrow">
# <td>X</td>
# <td>Jan. 18, 1976</td>
# <td>Orange Bowl (Miami)</td>
# <td>Pittsburgh 21, Dallas 17</td>
# </tr>
# <tr class="oddrow">
# <td>XI</td>
# <td>Jan. 9, 1977</td>
# <td>Rose Bowl (Pasadena, Calif.)</td>
# <td>Oakland 32, Minnesota 14</td>
# </tr>
# <tr class="evenrow">
# <td>XII</td>
# <td>Jan. 15, 1978</td>
# <td>Superdome (New Orleans)</td>
# <td>Dallas 27, Denver 10</td>
# </tr>
# <tr class="oddrow">
# <td>XIII</td>
# <td>Jan. 21, 1979</td>
# <td>Orange Bowl (Miami)</td>
# </table>

# %%
# Conversão da tabela HTML em um dataframe do Pandas
df = pd.read_html(str(table))[0]

# %%
df.head()
# Out:
#                                 0                               1  \
# 0  Super Bowl Winners and Results  Super Bowl Winners and Results
# 1                             NO.                            DATE
# 2                               I                   Jan. 15, 1967
# 3                              II                   Jan. 14, 1968
# 4                             III                   Jan. 12, 1969
#
#                                 2                               3
# 0  Super Bowl Winners and Results  Super Bowl Winners and Results
# 1                            SITE                          RESULT
# 2   Los Angeles Memorial Coliseum    Green Bay 35, Kansas City 10
# 3             Orange Bowl (Miami)        Green Bay 33, Oakland 14
# 4             Orange Bowl (Miami)   New York Jets 16, Baltimore 7

# %%
# Excluindo as duas primeiras linhas do dataframe
df = df.drop([0,1], axis=0)

# %%
df.head()
# Out:
#      0              1                              2  \
# 2    I  Jan. 15, 1967  Los Angeles Memorial Coliseum
# 3   II  Jan. 14, 1968            Orange Bowl (Miami)
# 4  III  Jan. 12, 1969            Orange Bowl (Miami)
# 5   IV  Jan. 11, 1970   Tulane Stadium (New Orleans)
# 6    V  Jan. 17, 1971            Orange Bowl (Miami)
#
#                                3
# 2   Green Bay 35, Kansas City 10
# 3       Green Bay 33, Oakland 14
# 4  New York Jets 16, Baltimore 7
# 5    Kansas City 23, Minnesota 7
# 6        Baltimore 16, Dallas 13

# %%
# Renomeando as colunas 
df = df.rename(columns={0:"Number", 1:"Date", 2:"Site", 3:"Result"})

# %%
df.head()
# Out:
#   Number           Date                           Site  \
# 2      I  Jan. 15, 1967  Los Angeles Memorial Coliseum
# 3     II  Jan. 14, 1968            Orange Bowl (Miami)
# 4    III  Jan. 12, 1969            Orange Bowl (Miami)
# 5     IV  Jan. 11, 1970   Tulane Stadium (New Orleans)
# 6      V  Jan. 17, 1971            Orange Bowl (Miami)
#
#                           Result
# 2   Green Bay 35, Kansas City 10
# 3       Green Bay 33, Oakland 14
# 4  New York Jets 16, Baltimore 7
# 5    Kansas City 23, Minnesota 7
# 6        Baltimore 16, Dallas 13

# %%
df.dtypes
# Out:
# Number    object
# Date      object
# Site      object
# Result    object
# dtype: object

# %%
# Convertendo a coluna de data para o tipo data
df['Date'] = pd.to_datetime(df.Date)

# %%
# Mudando o formato de data
df['Date'] = df['Date'].dt.strftime('%m/%d/%Y')

# %%
df.head()
# Out:
#   Number        Date                           Site  \
# 2      I  01/15/1967  Los Angeles Memorial Coliseum
# 3     II  01/14/1968            Orange Bowl (Miami)
# 4    III  01/12/1969            Orange Bowl (Miami)
# 5     IV  01/11/1970   Tulane Stadium (New Orleans)
# 6      V  01/17/1971            Orange Bowl (Miami)
#
#                           Result
# 2   Green Bay 35, Kansas City 10
# 3       Green Bay 33, Oakland 14
# 4  New York Jets 16, Baltimore 7
# 5    Kansas City 23, Minnesota 7
# 6        Baltimore 16, Dallas 13

# %%
# Separando a coluna Result em duas colunas Winner e Loser
df[['Winner', 'Loser']] = df['Result'].str.split(',', expand=True)

# %%
df.head()
# Out:
#   Number        Date                           Site  \
# 2      I  01/15/1967  Los Angeles Memorial Coliseum
# 3     II  01/14/1968            Orange Bowl (Miami)
# 4    III  01/12/1969            Orange Bowl (Miami)
# 5     IV  01/11/1970   Tulane Stadium (New Orleans)
# 6      V  01/17/1971            Orange Bowl (Miami)
#
#                           Result            Winner            Loser
# 2   Green Bay 35, Kansas City 10      Green Bay 35   Kansas City 10
# 3       Green Bay 33, Oakland 14      Green Bay 33       Oakland 14
# 4  New York Jets 16, Baltimore 7  New York Jets 16      Baltimore 7
# 5    Kansas City 23, Minnesota 7    Kansas City 23      Minnesota 7
# 6        Baltimore 16, Dallas 13      Baltimore 16        Dallas 13

# %%
# Removendo a coluna Result
df = df.drop(['Result'], axis=1)

# %%
df.head()
# Out:
#   Number        Date                           Site            Winner  \
# 2      I  01/15/1967  Los Angeles Memorial Coliseum      Green Bay 35
# 3     II  01/14/1968            Orange Bowl (Miami)      Green Bay 33
# 4    III  01/12/1969            Orange Bowl (Miami)  New York Jets 16
# 5     IV  01/11/1970   Tulane Stadium (New Orleans)    Kansas City 23
# 6      V  01/17/1971            Orange Bowl (Miami)      Baltimore 16
#
#              Loser
# 2   Kansas City 10
# 3       Oakland 14
# 4      Baltimore 7
# 5      Minnesota 7
# 6        Dallas 13

# %%
# Criando a coluna WinnerScore e LoserScore, extraindo os digitos das colunas Winner e Loser
df['WinnerScore'] = df['Winner'].str.extract('(\d+)')
df['LoserScore'] = df['Loser'].str.extract('(\d+)')

# %%
df.head()
# Out:
#   Number        Date                           Site            Winner  \
# 2      I  01/15/1967  Los Angeles Memorial Coliseum      Green Bay 35
# 3     II  01/14/1968            Orange Bowl (Miami)      Green Bay 33
# 4    III  01/12/1969            Orange Bowl (Miami)  New York Jets 16
# 5     IV  01/11/1970   Tulane Stadium (New Orleans)    Kansas City 23
# 6      V  01/17/1971            Orange Bowl (Miami)      Baltimore 16
#
#              Loser WinnerScore LoserScore
# 2   Kansas City 10          35         10
# 3       Oakland 14          33         14
# 4      Baltimore 7          16          7
# 5      Minnesota 7          23          7
# 6        Dallas 13          16         13

# %%
# Removendo os digitos das colunas Winner e Loser 
df['Winner'] = df['Winner'].str.replace('(\d+)', '')
df['Loser'] = df['Loser'].str.replace('(\d+)', '')

# %%
df.head()
# Out:
#   Number        Date                           Site          Winner  \
# 2      I  01/15/1967  Los Angeles Memorial Coliseum      Green Bay
# 3     II  01/14/1968            Orange Bowl (Miami)      Green Bay
# 4    III  01/12/1969            Orange Bowl (Miami)  New York Jets
# 5     IV  01/11/1970   Tulane Stadium (New Orleans)    Kansas City
# 6      V  01/17/1971            Orange Bowl (Miami)      Baltimore
#
#            Loser WinnerScore LoserScore
# 2   Kansas City           35         10
# 3       Oakland           33         14
# 4     Baltimore           16          7
# 5     Minnesota           23          7
# 6        Dallas           16         13

# %%
# Salvado a tabela em um arquivo csv
df.to_csv('SuperbowlResult.csv', index=False)

# %% [markdown]
# #### Fim
